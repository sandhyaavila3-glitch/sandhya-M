# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhyaavila3-glitch/sandhya-M/blob/main/finalproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
dp=files.upload()
# Out:
#      <input type="file" id="files-ae2c9ced-41d0-49aa-9e71-20576e9bb95e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae2c9ced-41d0-49aa-9e71-20576e9bb95e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel('value1.xlsx')
df
# Out:
#                                    url      label  url_length
# 0         http://update-info-alert.net   phishing        37.0
# 1                 https://flipkart.com        NaN         NaN
# 2   https://office365-authenticate.org   phishing        40.0
# 3         https://login-service.online        NaN         NaN
# 4                https://wikipedia.org  legtimate        19.0
# 5          https://netflix.com/account  legtimate         NaN
# 6       http://reward-points-claim.xyz   phishing        35.0
# 7           http://212.45.89.14/verify  legtimate        25.0
# 8            https://appleid.apple.com  legtimate        23.0
# 9           https://linkedin.com/login  legtimate        24.0
# 10        http://win-free-mobile.today   phishing        32.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   url         11 non-null     object
#  1   label       9 non-null      object
#  2   url_length  8 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 396.0+ bytes

# %%
df.describe()
# Out:
#        url_length
# count    8.000000
# mean    29.375000
# std      7.614601
# min     19.000000
# 25%     23.750000
# 50%     28.500000
# 75%     35.500000
# max     40.000000

# %%
df.isnull()
# Out:
#       url  label  url_length
# 0   False  False       False
# 1   False   True        True
# 2   False  False       False
# 3   False   True        True
# 4   False  False       False
# 5   False  False        True
# 6   False  False       False
# 7   False  False       False
# 8   False  False       False
# 9   False  False       False
# 10  False  False       False

# %%
df.isnull().sum()
# Out:
# url           0
# label         2
# url_length    3
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#                                    url      label  url_length
# 0         http://update-info-alert.net   phishing        37.0
# 1                 https://flipkart.com        NaN         NaN
# 2   https://office365-authenticate.org   phishing        40.0
# 3         https://login-service.online        NaN         NaN
# 4                https://wikipedia.org  legtimate        19.0
# 5          https://netflix.com/account  legtimate         NaN
# 6       http://reward-points-claim.xyz   phishing        35.0
# 7           http://212.45.89.14/verify  legtimate        25.0
# 8            https://appleid.apple.com  legtimate        23.0
# 9           https://linkedin.com/login  legtimate        24.0
# 10        http://win-free-mobile.today   phishing        32.0

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                    url      label  url_length
# 0         http://update-info-alert.net   phishing        37.0
# 1                 https://flipkart.com        NaN         NaN
# 2   https://office365-authenticate.org   phishing        40.0
# 3         https://login-service.online        NaN         NaN
# 4                https://wikipedia.org  legtimate        19.0
# 5          https://netflix.com/account  legtimate         NaN
# 6       http://reward-points-claim.xyz   phishing        35.0
# 7           http://212.45.89.14/verify  legtimate        25.0
# 8            https://appleid.apple.com  legtimate        23.0
# 9           https://linkedin.com/login  legtimate        24.0
# 10        http://win-free-mobile.today   phishing        32.0

# %%
df.dropna()
# Out:
#                                    url      label  url_length
# 0         http://update-info-alert.net   phishing        37.0
# 2   https://office365-authenticate.org   phishing        40.0
# 4                https://wikipedia.org  legtimate        19.0
# 6       http://reward-points-claim.xyz   phishing        35.0
# 7           http://212.45.89.14/verify  legtimate        25.0
# 8            https://appleid.apple.com  legtimate        23.0
# 9           https://linkedin.com/login  legtimate        24.0
# 10        http://win-free-mobile.today   phishing        32.0

# %%
df.fillna("no record")
# Out:
#                                    url      label url_length
# 0         http://update-info-alert.net   phishing       37.0
# 1                 https://flipkart.com  no record  no record
# 2   https://office365-authenticate.org   phishing       40.0
# 3         https://login-service.online  no record  no record
# 4                https://wikipedia.org  legtimate       19.0
# 5          https://netflix.com/account  legtimate  no record
# 6       http://reward-points-claim.xyz   phishing       35.0
# 7           http://212.45.89.14/verify  legtimate       25.0
# 8            https://appleid.apple.com  legtimate       23.0
# 9           https://linkedin.com/login  legtimate       24.0
# 10        http://win-free-mobile.today   phishing       32.0

# %%
df.drop(6)
# Out:
#                                    url      label  url_length
# 0         http://update-info-alert.net   phishing        37.0
# 1                 https://flipkart.com        NaN         NaN
# 2   https://office365-authenticate.org   phishing        40.0
# 3         https://login-service.online        NaN         NaN
# 4                https://wikipedia.org  legtimate        19.0
# 5          https://netflix.com/account  legtimate         NaN
# 7           http://212.45.89.14/verify  legtimate        25.0
# 8            https://appleid.apple.com  legtimate        23.0
# 9           https://linkedin.com/login  legtimate        24.0
# 10        http://win-free-mobile.today   phishing        32.0

# %%
df['url_length']=df['url_length'].replace("no record","0")

# %%
df
# Out:
#                                    url      label  url_length
# 0         http://update-info-alert.net   phishing        37.0
# 1                 https://flipkart.com        NaN         NaN
# 2   https://office365-authenticate.org   phishing        40.0
# 3         https://login-service.online        NaN         NaN
# 4                https://wikipedia.org  legtimate        19.0
# 5          https://netflix.com/account  legtimate         NaN
# 6       http://reward-points-claim.xyz   phishing        35.0
# 7           http://212.45.89.14/verify  legtimate        25.0
# 8            https://appleid.apple.com  legtimate        23.0
# 9           https://linkedin.com/login  legtimate        24.0
# 10        http://win-free-mobile.today   phishing        32.0

# %%
df['url_length']=df['url_length'].fillna(0)

# %%
df
# Out:
#                                    url      label  url_length
# 0         http://update-info-alert.net   phishing        37.0
# 1                 https://flipkart.com        NaN         0.0
# 2   https://office365-authenticate.org   phishing        40.0
# 3         https://login-service.online        NaN         0.0
# 4                https://wikipedia.org  legtimate        19.0
# 5          https://netflix.com/account  legtimate         0.0
# 6       http://reward-points-claim.xyz   phishing        35.0
# 7           http://212.45.89.14/verify  legtimate        25.0
# 8            https://appleid.apple.com  legtimate        23.0
# 9           https://linkedin.com/login  legtimate        24.0
# 10        http://win-free-mobile.today   phishing        32.0

# %%
df['lable']=df['label'].fillna("legitimate")

# %%
df
# Out:
#                                    url      label  url_length       lable
# 0         http://update-info-alert.net   phishing        37.0    phishing
# 1                 https://flipkart.com        NaN         0.0  legitimate
# 2   https://office365-authenticate.org   phishing        40.0    phishing
# 3         https://login-service.online        NaN         0.0  legitimate
# 4                https://wikipedia.org  legtimate        19.0   legtimate
# 5          https://netflix.com/account  legtimate         0.0   legtimate
# 6       http://reward-points-claim.xyz   phishing        35.0    phishing
# 7           http://212.45.89.14/verify  legtimate        25.0   legtimate
# 8            https://appleid.apple.com  legtimate        23.0   legtimate
# 9           https://linkedin.com/login  legtimate        24.0   legtimate
# 10        http://win-free-mobile.today   phishing        32.0    phishing

# %%
df['url_length']=df['url_length'].replace(0,25)

# %%
df
# Out:
#                                    url      label  url_length       lable
# 0         http://update-info-alert.net   phishing        37.0    phishing
# 1                 https://flipkart.com        NaN        25.0  legitimate
# 2   https://office365-authenticate.org   phishing        40.0    phishing
# 3         https://login-service.online        NaN        25.0  legitimate
# 4                https://wikipedia.org  legtimate        19.0   legtimate
# 5          https://netflix.com/account  legtimate        25.0   legtimate
# 6       http://reward-points-claim.xyz   phishing        35.0    phishing
# 7           http://212.45.89.14/verify  legtimate        25.0   legtimate
# 8            https://appleid.apple.com  legtimate        23.0   legtimate
# 9           https://linkedin.com/login  legtimate        24.0   legtimate
# 10        http://win-free-mobile.today   phishing        32.0    phishing

# %%
df['label']=df['label'].fillna('legtimate')

# %%
df
# Out:
#                                    url      label  url_length       lable
# 0         http://update-info-alert.net   phishing        37.0    phishing
# 1                 https://flipkart.com  legtimate        25.0  legitimate
# 2   https://office365-authenticate.org   phishing        40.0    phishing
# 3         https://login-service.online  legtimate        25.0  legitimate
# 4                https://wikipedia.org  legtimate        19.0   legtimate
# 5          https://netflix.com/account  legtimate        25.0   legtimate
# 6       http://reward-points-claim.xyz   phishing        35.0    phishing
# 7           http://212.45.89.14/verify  legtimate        25.0   legtimate
# 8            https://appleid.apple.com  legtimate        23.0   legtimate
# 9           https://linkedin.com/login  legtimate        24.0   legtimate
# 10        http://win-free-mobile.today   phishing        32.0    phishing

# %%
df.boxplot(column='url_length',by='label')
# Out:
# <Axes: title={'center': 'url_length'}, xlabel='label'>

# %%
df.boxplot(column='url_length',by='label')
# Out:
# <Axes: xlabel='lable'>

# %%
df.boxplot(column='url_length',by='label')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['label'].value_counts().plot.pie(autopct='%1.1f%%,figsize=(6,6)')
# Out:
# <Axes: ylabel='count'>

# %%
df = pd.read_excel("C:/Users/YourName/Downloads/value1.xlsx")
df.boxplot(column='url_length',by='label')
df.boxplot(column='url_length',by='label')
df.boxplot(column='url_length',by='label')
df['label'].value_counts().plot.pie(autopct='%1.1f%%,figsize=(6,6)')
# Out:
# <Axes: title={'center': 'url_length'}, ylabel='count'>
